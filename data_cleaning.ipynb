# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_excel('data/DS-2900-D02SC-MDDS.XLSX')

# %%
df1
# Out:
#     D-2 SC: MIGRANTS WITHIN THE STATE/UT CLASSIFIED BY PLACE OF LAST RESIDENCE, SEX AND DURATION OF RESIDENCE IN PLACE OF ENUMERATION FOR SCHEDULED CASTE - 2011  \
# 0                                           Table name
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                              D0402SC
# ..                                                 ...
# 931                                            D0402SC
# 932                                            D0402SC
# 933                                            D0402SC
# 934                                                NaN
# 935  Note:    The place of last residence unclassif...
#
#     Unnamed: 1 Unnamed: 2         Unnamed: 3         Unnamed: 4  \
# 0        State   District          Area Name           Place of
# 1          NaN        NaN                NaN        enumeration
# ...
