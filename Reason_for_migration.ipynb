# %% [markdown]
# <a href="https://colab.research.google.com/github/SuprajaYadavH/Hackathon/blob/Supraja/Reason_for_migration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-67c779b9-f13b-43f1-80c3-f0f044921d7c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-67c779b9-f13b-43f1-80c3-f0f044921d7c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_excel("Migrants_by_reason_of_migration(c).xlsx", header=1, skiprows=[2, 3])

# %%
data. head()
# Out:
#   Table name  State  District          Area Name Place of enumeration  \
# 0      D0603   29.0       0.0  State - KARNATAKA                Total
# 1      D0603   29.0       0.0  State - KARNATAKA                Total
# 2      D0603   29.0       0.0  State - KARNATAKA                Total
# 3      D0603   29.0       0.0  State - KARNATAKA                Total
# 4      D0603   29.0       0.0  State - KARNATAKA                Total
#
#         Duration of residence  \
# 0  All durations of residence
# 1  All durations of residence
# 2  All durations of residence
# 3  All durations of residence
# 4  All durations of residence
#
#                                       Last residence Last residence.1  \
# 0                                              Total            Total
# 1                        Last residence within India            Total
# 2                        Last residence within India            Rural
# 3                        Last residence within India            Urban
# ...

# %%
data.shape
# Out:
# (58128, 32)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58128 entries, 0 to 58127
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Table name                     58127 non-null  object
#  1   State                          58125 non-null  float64
#  2   District                       58125 non-null  float64
#  3   Area Name                      58125 non-null  object
#  4   Place of enumeration           58125 non-null  object
#  5   Duration of residence          58125 non-null  object
#  6   Last residence                 58125 non-null  object
#  7   Last residence.1               58125 non-null  object
#  8   Total migrants(Persons)        58125 non-null  float64
#  9   Total migrants(Males)          58125 non-null  float64
#  10  Total migrants(Females)        58125 non-null  float64
#  11  Work/employment(Persons)       58125 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# Table name                       1
# State                            3
# District                         3
# Area Name                        3
# Place of enumeration             3
# Duration of residence            3
# Last residence                   3
# Last residence.1                 3
# Total migrants(Persons)          3
# Total migrants(Males)            3
# Total migrants(Females)          3
# Work/employment(Persons)         3
# Work/employment(Males)           3
# Work/employment(Females)         3
# Business(Persons)                3
# Business(Males)                  3
# Business(Females)                3
# Education(Persons)               3
# Education(Males)                 3
# Education(Females)               3
# Marriage(Persons)                3
# Marriage(Males)                  3
# Marriage(Females)                3
# Moved after birth(Persons)       3
# Moved after birth(Males)         3
# Moved after birth(Females)       3
# Moved with household(Persons)    3
# ...

# %%
data.dropna(axis=0,inplace=True)

# %%
data.isnull().sum()
# Out:
# Table name                       0
# State                            0
# District                         0
# Area Name                        0
# Place of enumeration             0
# Duration of residence            0
# Last residence                   0
# Last residence.1                 0
# Total migrants(Persons)          0
# Total migrants(Males)            0
# Total migrants(Females)          0
# Work/employment(Persons)         0
# Work/employment(Males)           0
# Work/employment(Females)         0
# Business(Persons)                0
# Business(Males)                  0
# Business(Females)                0
# Education(Persons)               0
# Education(Males)                 0
# Education(Females)               0
# Marriage(Persons)                0
# Marriage(Males)                  0
# Marriage(Females)                0
# Moved after birth(Persons)       0
# Moved after birth(Males)         0
# Moved after birth(Females)       0
# Moved with household(Persons)    0
# ...

# %%
data["Area Name"].value_counts()
# Out:
# State - KARNATAKA    1875
# Chikmagalur          1875
# Bangalore Rural      1875
# Chikkaballapura      1875
# Kolar                1875
# Yadgir               1875
# Gulbarga             1875
# Chamarajanagar       1875
# Mysore               1875
# Kodagu               1875
# Dakshina Kannada     1875
# Hassan               1875
# Mandya               1875
# Bangalore            1875
# Tumkur               1875
# Udupi                1875
# Belgaum              1875
# Shimoga              1875
# Davanagere           1875
# Chitradurga          1875
# Bellary              1875
# Haveri               1875
# Uttara Kannada       1875
# Dharwad              1875
# Gadag                1875
# Koppal               1875
# Raichur              1875
# Bidar                1875
# Bijapur              1875
# Bagalkot             1875
# Ramanagara           1875
# Name: Area Name, dtype: int64

# %%
#taking only bangalore data
blr_data = data.loc[data['Area Name'].isin(['Bangalore', 'Bangalore Rural']), :]

# %%
blr_data
# Out:
#       Table name  State  District        Area Name Place of enumeration  \
# 33750      D0603   29.0     572.0        Bangalore                Total
# 33751      D0603   29.0     572.0        Bangalore                Total
# 33752      D0603   29.0     572.0        Bangalore                Total
# 33753      D0603   29.0     572.0        Bangalore                Total
# 33754      D0603   29.0     572.0        Bangalore                Total
# ...          ...    ...       ...              ...                  ...
# 56245      D0603   29.0     583.0  Bangalore Rural                Urban
# 56246      D0603   29.0     583.0  Bangalore Rural                Urban
# 56247      D0603   29.0     583.0  Bangalore Rural                Urban
# 56248      D0603   29.0     583.0  Bangalore Rural                Urban
# 56249      D0603   29.0     583.0  Bangalore Rural                Urban
#
#                           Duration of residence  \
# 33750                All durations of residence
# ...

# %%
blr_data["District"].value_counts()
# Out:
# 572.0    1875
# 583.0    1875
# Name: District, dtype: int64

# %%
# explain this?
blr_data["Place of enumeration"].value_counts()
# Out:
# Total    1250
# Rural    1250
# Urban    1250
# Name: Place of enumeration, dtype: int64

# %%
blr_data["Duration of residence"].value_counts()
# Out:
# All durations of residence                  750
# Duration of residence less than 1 year      750
# Duration of residence 1-4 years             750
# Duration of residence 5-9 years             750
# Duration of residence 10 years and above    750
# Name: Duration of residence, dtype: int64

# %%
blr_data["Last residence"].value_counts()
# Out:
# Meghalaya                                                               90
# Last residence within India                                             90
# West Bengal                                                             90
# Jharkhand                                                               90
# Odisha                                                                  90
# Chhattisgarh                                                            90
# Madhya Pradesh                                                          90
# Gujarat                                                                 90
# Daman & Diu                                                             90
# Dadra & Nagar Haveli                                                    90
# Maharashtra                                                             90
# Andhra Pradesh                                                          90
# ...

# %%
blr_data["Last residence.1"].value_counts()
# Out:
# Total    1350
# Rural    1200
# Urban    1200
# Name: Last residence.1, dtype: int64

# %%
blr_total=(blr_data['Last residence.1']=="Total")& (blr_data["Place of enumeration"]=="Total")& (blr_data["Duration of residence"]=="All durations of residence")

# %%
blr_data[blr_total]
# Out:
#       Table name  State  District        Area Name Place of enumeration  \
# 33750      D0603   29.0     572.0        Bangalore                Total
# 33751      D0603   29.0     572.0        Bangalore                Total
# 33754      D0603   29.0     572.0        Bangalore                Total
# 33757      D0603   29.0     572.0        Bangalore                Total
# 33760      D0603   29.0     572.0        Bangalore                Total
# ...          ...    ...       ...              ...                  ...
# 54493      D0603   29.0     583.0  Bangalore Rural                Total
# 54496      D0603   29.0     583.0  Bangalore Rural                Total
# 54497      D0603   29.0     583.0  Bangalore Rural                Total
# 54498      D0603   29.0     583.0  Bangalore Rural                Total
# 54499      D0603   29.0     583.0  Bangalore Rural                Total
#
#             Duration of residence  \
# 33750  All durations of residence
# ...

# %%
blr_1=(blr_data['Last residence.1']=="Urban")& (blr_data["Place of enumeration"]=="Urban")& (blr_data["Duration of residence"]=="All durations of residence")

# %%
blr_urban =blr_data[blr_1]

# %%
blr_urban.to_csv("blr_urban(UU).csv")

# %%
blr_2=(blr_data['Last residence.1']=="Urban")& (blr_data["Place of enumeration"]=="Rural")& (blr_data["Duration of residence"]=="All durations of residence")

# %%
blr_urban_to_rural=blr_data[blr_2]

# %%
blr_urban_to_rural.to_csv("blr_urban(UR).csv")

# %%
blr_3=(blr_data['Last residence.1']=="Rural")& (blr_data["Place of enumeration"]=="Urban")& (blr_data["Duration of residence"]=="All durations of residence")

# %%
blr_rural_to_urban=blr_data[blr_3]

# %%
blr_rural_to_urban.to_csv("blr_Rural(RU).csv")

# %%
blr_4=(blr_data['Last residence.1']=="Rural")& (blr_data["Place of enumeration"]=="Rural")& (blr_data["Duration of residence"]=="All durations of residence")

# %%
blr_rural_to_rural=blr_data[blr_4]

# %%
blr_rural_to_rural.to_csv("blr_Rural(RR).csv")

# %%
blr_data.drop(["Table name","State","District"],axis=1,inplace=True)
# Out:
# <ipython-input-21-7df514ca1589>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   blr_data.drop(["Table name","State","District"],axis=1,inplace=True)

# %%
blr_data.head()
# Out:
#        Area Name Place of enumeration       Duration of residence  \
# 33750  Bangalore                Total  All durations of residence
# 33751  Bangalore                Total  All durations of residence
# 33752  Bangalore                Total  All durations of residence
# 33753  Bangalore                Total  All durations of residence
# 33754  Bangalore                Total  All durations of residence
#
#                                           Last residence Last residence.1  \
# 33750                                              Total            Total
# 33751                        Last residence within India            Total
# 33752                        Last residence within India            Rural
# 33753                        Last residence within India            Urban
# 33754  Within the state of enumeration but outside th...            Total
#
#        Total migrants(Persons)  Total migrants(Males)  \
# 33750                5140755.0              2706024.0
# ...

# %%
blr_data.to_csv("blr_data.csv", index=True)
